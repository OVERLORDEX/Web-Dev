# %% [markdown]
# <<Lesson 4: CSS text properties>>
#
# #Challenge: Fancy font families
#
# ![alt text](<Снимок экрана 2026-01-27 025445.png>)

# %% [markdown]
# ```<!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="utf-8">
#         <title>Challenge: Fancy font families</title>
#         <style>
#         body {
#             font-family: fantasy;
#         }
#         #flinstones {
#             font-family: sans-serif;
#         }
#
#         #jetsons {
#             font-family: serif;
#         }
#
#         #addams {
#             font-family: fantasy;
#         }
#         </style>
#     </head>
#     <body>
#
#     <p>Some fun theme songs of well known TV families...</p>
#
#     <h4>The Flinstones</h4>
#     <p id="flinstones">
#     Meet the Flintstones<br>
#     They're the modern stone age family<br>
#     From the town of Bedrock<br>
#     They're a page right of history</p>
#
#     <h4>The Jetsons</h4>
#     <p id="jetsons">
#     Meet George Jetson,<br>
#     His Boy Elroy,<br>
#     Daughter Judy,<br>
#     Jane, His wife
#     </p>
#
#     <h4>The Addams Family</h4>
#     <p id="addams">
#     They're creepy and they're kooky,<br>
#     mysterious and spooky<br>
#     They're all together ooky,<br>
#     the Addams Family
#     </p>
#     </body>
# </html>

# %% [markdown]
# #Challenge: Great big font sizes
#
# ![alt text](<Снимок экрана 2026-01-27 025645.png>)

# %% [markdown]
# ```<!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="utf-8">
#         <title>Challenge: Great big font sizes</title>
#         <style>
#             .big {
#                 font-size:50;
#             }
#
#             .bigger {
#                 font-size: 100;
#             }
#         </style>
#     </head>
#     <body>
#
# <h1>Great Big Words</h1>
# <h2>by Michael Mark & Tom Chapin</h2>
#
# <p>When I was a little kid,
# a "<em class="big">diminutive juvenile</em>," <br>
# I liked my folks to read to me,
# I was an <em class="big">"eager bibliophile."</em> <br>
# Now I love words for how they sound <br>
# And how they <em class="big">"communicate."</em> <br>
# Perhaps I should explain myself,
# that is, <em class="big">"elucidate."</em> <br>
# Great big words, I like <em class="big">big</em> words. <br>
# Letter by letter, the <em class="bigger">bigger</em> the better <br>
# Great big words. La la la la la la la la la la!</p>
#
#     </body>
# </html>

# %% [markdown]
# #Challenge: Famous font formats
#
# ![alt text](<Снимок экрана 2026-01-27 025740.png>)

# %% [markdown]
# ```<!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="utf-8">
#         <title>Challenge: Famous font formats</title>
#         <style>
#             .declaration {
#                 font-weight:bold;
#             }
#
#             .quote {
#                 font-style:italic;
#             }
#         </style>
#     </head>
#     <body>
#
#     <h2>Famous quotes</h2>
#     <p class="quote">
#     "My mama always said life was like a box of chocolates. You never know what you're gonna get.".
#     <br> - Forrest Gump
#     </p>
#
#     <p class="quote">
#     "May the force be with you."
#     <br>- Star Wars
#     </p>
#
#      <h2>Famous declarations</h2>
#
#     <p class="declaration">
#     I'M BATMAN.
#     </p>
#
#     <p class="declaration">
#     Earth, water, fire. Together, we are CAPTAIN PLANET!
#     </p>
#
#     </body>
# </html>

# %% [markdown]
# #Project: Blog
#
# ![alt text](<Снимок экрана 2026-01-27 030853.png>)

# %% [markdown]
# ```<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>Project: Blog</title>
#
#     <style>
#       body {
#         font-family: serif;
#         background-color: lightgray;
#       }
#
#       h1 {
#         font-family: sans-serif;
#         color: black;
#       }
#
#       h2 {
#         color: brown;
#       }
#
#       h3 {
#         font-family: sans-serif;
#       }
#
#       .date {
#         font-style: italic;
#         color: #777;
#       }
#
#       .post {
#         background-color: white;
#       }
#
#       a {
#         color: green;
#         text-decoration: none;
#       }
#
#       a:hover {
#         text-decoration: underline;
#       }
#     </style>
#   </head>
#
#   <body>
#
#     <h1>Dante's blog</h1>
#
#     <h3>Contents</h3>
#     <ul>
#       <li><a href="#post1">First post</a></li>
#       <li><a href="#post2">Second post</a></li>
#     </ul>
#
#     <div class="post">
#       <h2 id="post1">First post</h2>
#       <p class="date">Posted on February 2026</p>
#       <p>
#         Today I started my own practice "how to destroy enemy on 2 move.
#       </p>
#     </div>
#
#     <div class="post">
#       <h2 id="post2">Second post</h2>
#       <p class="date">Posted two years later</p>
#       <p>
#         I am a strongest demon hunter for history.
#       </p>
#     </div>
#
#   </body>
# </html>
